# %% [markdown]
# ### Objective: Master string operations, explore Python datatypes deeply, and use operators effectively.

# %% [markdown]
# Topics Covered:
#
# 1. Strings and String Operations
# 2. String Methods
# 3. Indexing and Slicing
# 4. Comparison & Logical Operators
# 5. Type Casting (continued)

# %% [markdown]
# ### Interviewer Questions
# 1. What are immutable data types in Python? Is a string mutable?
# 2. Differentiate between == and is operators with examples.
# 3. Explain how indexing works in Python strings.
# 4. List any 5 string methods and their purpose.
# 5. How are logical operators and, or, and not used?

# %% [markdown]
# ### 1. String Basics

# %% [markdown]
# ###### Task: Create a string variable called 'college' and assign it your college name.
# ###### Print the first, middle, and last character using indexing.

# %% [markdown]
# ### 2. String Slicing

# %% [markdown]
# ###### Task: Create a variable 'course' = "Industrial Python Internship"
# ###### Slice and print:
# ###### - The word "Python"
# ###### - The word "Intern"
# ###### - The entire phrase in reverse

# %% [markdown]
# ###  3. String Methods

# %% [markdown]
# ### Task: Use string methods on a sentence:
# sentence = "python internship at algonex"
#
# ###### - Convert to title case
# ###### - Replace "algonex" with "Microsoft"
# ###### - Count the occurrence of 't'
# ###### - Check if sentence starts with "python"
# ###### - Find index of word "intern"

# %% [markdown]
# ### 4.  Comparison & Logical Operators

# %% [markdown]
# """ # Task: Create 3 variables: age = 21, name = "Alice", is_intern = True
#  Write conditions to:
#  - Check if age is greater than 18 and is_intern is True
#  - Check if name is not equal to "Bob"
#  - Check if age is between 20 and 25
# """

# %% [markdown]
# ### Type Casting Practice

# %% [markdown]
# """ 1.  Task: Convert float to int, string to float, int to string
#
# 2.  Print types after each conversion """

# %% [markdown]
# ## Submit in GitHub repo name it as Day2_Python_Algonex_tasks
